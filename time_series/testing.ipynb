# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rc('figure', figsize=(11, 9))
plt.rc('font', size=13)

import requests
import os

import warnings
warnings.filterwarnings("ignore")

import acquire_walkthrough

# %%
df = acquire_walkthrough.big_df()
df.head()
# Out:
#                            sale_amount  sale_id           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1  12125 Alamo Ranch Pkwy
# 2013-01-02 00:00:00+00:00         11.0        2  12125 Alamo Ranch Pkwy
# 2013-01-03 00:00:00+00:00         14.0        3  12125 Alamo Ranch Pkwy
# 2013-01-04 00:00:00+00:00         13.0        4  12125 Alamo Ranch Pkwy
# 2013-01-05 00:00:00+00:00         10.0        5  12125 Alamo Ranch Pkwy
#
#                             store_city  store_id store_state  store_zipcode  \
# sale_date
# 2013-01-01 00:00:00+00:00  San Antonio         1          TX          78253
# 2013-01-02 00:00:00+00:00  San Antonio         1          TX          78253
# 2013-01-03 00:00:00+00:00  San Antonio         1          TX          78253
# 2013-01-04 00:00:00+00:00  San Antonio         1          TX          78253
# 2013-01-05 00:00:00+00:00  San Antonio         1          TX          78253
#
#                           item_brand  item_id                       item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
# 2013-01-02 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
# 2013-01-03 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
# 2013-01-04 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
# 2013-01-05 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
#
#                            item_price   item_upc12   item_upc14
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-02 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-03 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-04 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-05 00:00:00+00:00        0.84  35200264013  35200264013

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10000 entries, 2013-01-01 00:00:00+00:00 to 2015-05-20 00:00:00+00:00
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sale_amount    10000 non-null  float64
#  1   sale_id        10000 non-null  int64
#  2   store_address  10000 non-null  object
#  3   store_city     10000 non-null  object
#  4   store_id       10000 non-null  int64
#  5   store_state    10000 non-null  object
#  6   store_zipcode  10000 non-null  int64
#  7   item_brand     10000 non-null  object
#  8   item_id        10000 non-null  int64
#  9   item_name      10000 non-null  object
#  10  item_price     10000 non-null  float64
#  11  item_upc12     10000 non-null  int64
#  12  item_upc14     10000 non-null  int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 1.1+ MB

# %%
df.groupby('store_id')['sale_amount'].resample('W').plot()
# Out:
# store_id  sale_date
# 1         2013-01-06 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
#           2013-01-13 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
#           2013-01-20 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
#           2013-01-27 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
#           2013-02-03 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
#                                                        ...
# 6         2015-04-26 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
#           2015-05-03 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
#           2015-05-10 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
#           2015-05-17 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
#           2015-05-24 00:00:00+00:00    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: sale_amount, Length: 1430, dtype: object

# %%
gdf = acquire_walkthrough.german_energy_csv()
gdf.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %%
gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4383 entries, 2006-01-01 to 2017-12-31
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Consumption  4383 non-null   float64
#  1   Wind         2920 non-null   float64
#  2   Solar        2188 non-null   float64
#  3   Wind+Solar   2187 non-null   float64
# dtypes: float64(4)
# memory usage: 171.2 KB

# %%
gdf.plot()
