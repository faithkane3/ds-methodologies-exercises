# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rc('figure', figsize=(11, 9))
plt.rc('font', size=13)

import requests
import os

import warnings
warnings.filterwarnings("ignore")

import acquire_walkthrough

# %%
df = acquire_walkthrough.get_store_data()
df.head()
# Out:
#                            sale_amount  sale_id            store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1   12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00         19.0     3653  2118 Fredericksburg Rdj
# 2013-01-01 00:00:00+00:00         11.0     7305          1520 Austin Hwy
# 2013-01-01 00:00:00+00:00         12.0     1827         9255 FM 471 West
# 2013-01-01 00:00:00+00:00         20.0     9131       1015 S WW White Rd
#
#                             store_city  store_id store_state store_zipcode  \
# sale_date
# 2013-01-01 00:00:00+00:00  San Antonio         1          TX         78253
# 2013-01-01 00:00:00+00:00  San Antonio         3          TX         78201
# 2013-01-01 00:00:00+00:00  San Antonio         5          TX         78218
# 2013-01-01 00:00:00+00:00  San Antonio         2          TX         78251
# 2013-01-01 00:00:00+00:00  San Antonio         6          TX         78220
#
#                           item_brand  item_id                       item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00   Riceland        1  Riceland American Jazmine Rice
#
#                            item_price   item_upc12   item_upc14
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10000 entries, 2013-01-01 00:00:00+00:00 to 2017-12-31 00:00:00+00:00
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sale_amount    10000 non-null  float64
#  1   sale_id        10000 non-null  int64
#  2   store_address  10000 non-null  object
#  3   store_city     10000 non-null  object
#  4   store_id       10000 non-null  int64
#  5   store_state    10000 non-null  object
#  6   store_zipcode  10000 non-null  object
#  7   item_brand     10000 non-null  object
#  8   item_id        10000 non-null  int64
#  9   item_name      10000 non-null  object
#  10  item_price     10000 non-null  float64
#  11  item_upc12     10000 non-null  object
#  12  item_upc14     10000 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.1+ MB

# %%
df.store_id.value_counts()
# Out:
# 5    1826
# 4    1826
# 3    1826
# 2    1826
# 1    1826
# 6     870
# Name: store_id, dtype: int64

# %%
df['sale_amount'].plot()

# %%
gdf = acquire_walkthrough.german_energy_csv()
gdf.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %%
gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4383 entries, 2006-01-01 to 2017-12-31
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Consumption  4383 non-null   float64
#  1   Wind         2920 non-null   float64
#  2   Solar        2188 non-null   float64
#  3   Wind+Solar   2187 non-null   float64
# dtypes: float64(4)
# memory usage: 171.2+ KB

# %%
gdf.plot()
